# %%
#list in python
#List is an Ordered and Changable collection that can store multiple values
marks=[80,90,75,85]

print(marks)
# Out:
# [80, 90, 75, 85]

# %%
#accessing elements in list
marks=[80, 90, 75,85]
print(marks[0])
print(marks[1])
print(marks[2])
# Out:
# 80
# 90
# 75

# %%
#changing elemnets sin list
marks[1]=95
print(marks)
# Out:
# [80, 95, 75, 85]

# %%
marks=[79,64,92,74,96,77,94]
marks[1]=99
marks[3]=99
marks[5]=99
print(marks)
# Out:
# [79, 99, 92, 99, 96, 99, 94]

# %%
#add elements to a list
marks=[80, 90, 75]
marks.append(85)
print(marks)
# Out:
# [80, 90, 75, 85]

# %%
marks=[80, 90, 70, 60, 50]
marks.append(100)
print(marks)
# Out:
# [80, 90, 70, 60, 50, 100]

# %%
marks=[10, 20, 30, 40, 50, 61]
marks[5]=60
marks.append(70)
print(marks)
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
marks=[80, 90, 75]
marks.remove(90)
print(marks)
# Out:
# [80, 75]

# %%
n=[1,3,4,5]
n.insert(1,2)
print(n)
# Out:
# [1, 2, 3, 4, 5]

# %%
#bitwise operator
# if both operators are true it returns true or else false
5>>3
# Out:
# 0

# %%
15>>3
# Out:
# 1

# %%
13>>1
# Out:
# 6

# %%
7>>2
# Out:
# 1

# %%
9>>2
# Out:
# 2

# %%
15<<6
# Out:
# 960

# %%
11<5
# Out:
# False

# %%
11<<5
# Out:
# 352

# %%
12<<4
# Out:
# 192

# %%
14<<7
# Out:
# 1792

# %%
#extend in list
a=[1,2,3]
b=[4,5,6]
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#clearing all elements in list
a=[1,2,3]
a.clear()
print(a)
# Out:
# []

# %%
#knowing index value
a=[1,2,3]
print(a.index(2))
# Out:
# 1

# %%
#knowing count
n=[1,2,3,4,2,5,2,6]
print(n.count(2))
# Out:
# 3

# %%
#sort
#Ascending order
n=[10,50,60,20,30,40]
n.sort()
print(n)
#Descending order
n.sort(reverse=True)
print(n)
# Out:
# [10, 20, 30, 40, 50, 60]
# [60, 50, 40, 30, 20, 10]

# %%
#reverse
n=[1,2,4,3]
n.reverse
print(n)
# Out:
# [1, 2, 4, 3]

# %%
#copy
a=[1,2,3]
b=a.copy()
print(b)
# Out:
# [1, 2, 3]

# %%
numbers=[1,2,3,4,5]
print(numbers[1:4])
print(numbers[:3])
print(numbers[2:])
print(numbers[::2])
print(numbers[0:4:-2])
print(numbers[::-3])
# Out:
# [2, 3, 4]
# [1, 2, 3]
# [3, 4, 5]
# [1, 3, 5]
# []
# [5, 2]
