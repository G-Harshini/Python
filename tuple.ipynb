# %%
#Immutable nature of tuples
n=(1,2,3,4,5,6)
n[4]=6
#This gives error because we cannot modify it
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 n=(1,2,3,4,5,6)
# ----> 2 n[4]=6
#
# TypeError: 'tuple' object does not support item assignment

# %%
#count
n=(10,20,30,20,40,20)
print(n.count(20))
# Out:
# 3

# %%
#index
n=(10,20,30,20,40,20)
print(n.index(40))
# Out:
# 4

# %%
#sets
#it do not allow duplicate values, it is unordered and unique , it is mutable.

# %%
n={1,2,3,2,4}
print(n)
# Out:
# {1, 2, 3, 4}

# %%
n={1,2,4,5,6}
n.add(3)
print(n)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
n={1,2,3}
n.remove(2)
print(n)
# Out:
# {1, 3}

# %%
#Dictionaries
#It is a collection of key-value paires that is unordered and mutable
student={"name":"Harshini" ,"age":17}
print(student)
# Out:
# {'name': 'Harshini', 'age': 17}

# %%
#accessing
student={"name":"Harshini" ,"age":17}
print(student["name"])
# Out:
# Harshini

# %%
#Adding new data to dictionary 
student["city"]="nellore"
print(student)
# Out:
# {'name': 'Harshini', 'age': 17, 'city': 'nellore'}

# %%
print(student.keys())
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
print(student.values())
# Out:
# dict_values(['Harshini', 17, 'nellore'])

# %%
print(student.get("name"))
# Out:
# Harshini

# %%
print(student.get("age"))
# Out:
# 17

# %%
student.popitem()
print(student)
# Out:
# {'name': 'Harshini', 'age': 17}

# %%
student.pop("age")
# Out:
# 17

# %%
print(student)
# Out:
# {'name': 'Harshini'}

# %%
student.setdefault("age" , 18)
print(student)
# Out:
# {'name': 'Harshini', 'age': 18}

# %%
student.popitem()
# Out:
# ('age', 18)

# %%
print(student)
# Out:
# {'name': 'Harshini'}

# %%
student.setdefault("age" , 18)
print(student)
# Out:
# {'name': 'Harshini', 'age': 18}

# %%
student.pop("age")
# Out:
# 18

# %%
print(student)
# Out:
# {'name': 'Harshini'}
